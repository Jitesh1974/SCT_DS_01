# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
full_df = pd.read_csv('/content/API_SP.POP.TOTL_DS2_en_csv_v2_1019308.csv', skiprows=4)
metadata_df = pd.read_csv('/content/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_23043.csv')

# %%
full_df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %%
true_countries_df = metadata_df[metadata_df['Region'].notna()]


countries_only_df = full_df[full_df['Country Code'].isin(true_countries_df['Country Code'])]


top_5_df = countries_only_df.sort_values(by='2024', ascending=False).head(5)

# %%
print("--- Correct Top 5 Most Populous Countries in 2024 ---")
print(top_5_df[['Country Name', '2024']])
# Out:
# --- Correct Top 5 Most Populous Countries in 2024 ---
#       Country Name          2024
# 109          India  1.450936e+09
# 40           China  1.408975e+09
# 251  United States  3.401110e+08
# 106      Indonesia  2.834879e+08
# 184       Pakistan  2.512692e+08

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12, 8))

sns.barplot(
    x='Country Name',
    y='2024',
    data=top_5_df,
    palette='plasma'
)

plt.xticks(rotation=45, ha='right')


plt.title('Top 5 Most Populous Countries (2024)', fontsize=16)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Total Population (in billions)', fontsize=12)


plt.tight_layout()
# Out:
# /tmp/ipython-input-2746064904.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.savefig('top_5_population_corrected_chart.png')
print("\nCorrected bar chart saved as 'top_5_population_corrected_chart.png'")
# Out:
# Corrected bar chart saved as 'top_5_population_corrected_chart.png'
